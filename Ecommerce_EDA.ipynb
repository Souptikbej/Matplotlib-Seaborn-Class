# %% [markdown]
# <a href="https://colab.research.google.com/github/Souptikbej/Matplotlib-Seaborn-Class/blob/main/Ecommerce_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **E-Commerce Sales Analysis**
#
# ## Phase 2: Dataset Understanding
#
# ### Objective
#
# The objective of this phase is to understand the dataset before performing any data cleaning or analysis.
#
# During this phase, we will:
#
# - Load the dataset
# - Inspect its structure
# - Understand each column
# - Identify data types
# - Explore summary statistics
# - Build a data dictionary
# - Detect potential data quality issues
#
# Understanding the dataset helps ensure accurate and meaningful analysis in later stages.

# %%
import pandas as pd
import numpy as np
